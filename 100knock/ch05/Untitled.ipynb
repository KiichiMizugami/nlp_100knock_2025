# %% [markdown]
# # 第5章: 大規模言語モデル
# この章では、大規模言語モデル (LLM; Large Language Model) の利用し、様々なタスクに取り組む。大規模言語モデルをプログラムからAPI経由で呼び出すことを想定しており、そのAPIの利用で費用が発生する可能性があることに留意せよ。

# %%
import sys
print(sys.executable)
# Out:
# '3.11.1 (Python 3.11.1)' でセルを実行するには、 ipykernel パッケージが必要です。
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Python 環境の作成</a> および必要なパッケージ。
#
# または、次のコマンドを使用して 'ipykernel' をインストールします: '/Users/mizukamikiichi/.pyenv/versions/3.11.1/bin/python -m pip install ipykernel -U --force-reinstall'

# %%
import sys
print(sys.executable)
# Out:
# /Users/mizukamikiichi/.pyenv/versions/100knock/bin/python

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.device_count())
print(torch.cuda.get_device_name(0))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 import torch
#       2 print(torch.cuda.is_available())
#       3 print(torch.cuda.device_count())
#
# ModuleNotFoundError: No module named 'torch'

# %%
pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (1.3.2)
# Requirement already satisfied: packaging>=20.9 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (2026.1.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: typer-slim in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (0.21.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: filelock in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (3.20.3)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: shellingham in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from huggingface_hub) (1.5.4)
# Requirement already satisfied: idna in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.11)
# Requirement already satisfied: anyio in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: certifi in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.1.4)
# Requirement already satisfied: h11>=0.16 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from typer-slim->huggingface_hub) (8.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/mizukamikiichi/.pyenv/versions/3.10.5/envs/100knock/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->huggingface_hub) (1.3.1)
# WARNING: You are using pip version 22.0.4; however, version 25.3 is available.
# You should consider upgrading via the '/Users/mizukamikiichi/.pyenv/versions/100knock/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import transformers
print(transformers.__version__)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 import transformers
#       2 print(transformers.__version__)
#
# ModuleNotFoundError: No module named 'transformers'

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "Qwen/Qwen2.5-3B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    trust_remote_code=True,
    device_map="auto"
)

# %% [markdown]
# # 40. Zero-Shot推論
# 以下の問題の解答を作成せよ。ただし、解答生成はzero-shot推論とせよ。

# %% [markdown]
# """
# 9世紀に活躍した人物に関係するできごとについて述べた次のア～ウを年代の古い順に正しく並べよ。
#
# ア　藤原時平は，策謀を用いて菅原道真を政界から追放した。
# イ　嵯峨天皇は，藤原冬嗣らを蔵人頭に任命した。
# ウ　藤原良房は，承和の変後，藤原氏の中での北家の優位を確立した。"""

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "Qwen/Qwen2.5-3B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(
    model_name,
    trust_remote_code=True
)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    trust_remote_code=True,
    device_map="auto",
    torch_dtype=torch.float16
)

prompt = """9世紀に活躍した人物に関係するできごとについて述べた次のア～ウを、
年代の古い順に正しく並べよ。
ア 藤原時平は，策謀を用いて菅原道真を政界から追放した。
イ 嵯峨天皇は，藤原冬嗣らを蔵人頭に任命した。
ウ 藤原良房は，承和の変後，藤原氏の中での北家の優位を確立した。
"""

inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

with torch.no_grad():
    outputs = model.generate(
        **inputs,
        max_new_tokens=100,
        temperature=0.0,
        do_sample=False
    )

print(tokenizer.decode(outputs[0], skip_special_tokens=True))

# %%
import sys, transformers
print(sys.executable)
print(transformers.__version__)

# %% [markdown]
# # 41. Few-Shot推論
# 以下の問題と解答を与え、問題40で示した質問の解答をfew-shot推論（この場合は4-shot推論）で生成せよ。
